# %%
padi = {}
kedelai = {}

totPadi = 0
totKedelai = 0
totJagung = 0

def kriteria():
    for lokasi, data in data_panen.items():
        if data['hasil_panen']['padi'] > 1300 or data['hasil_panen']['jagung'] > 800:
            print(f"{data['nama_lokasi']}: Butuh perhatian khusus")
        else:
            print(f"{data['nama_lokasi']}: Kondisi baik")

def jumlah():
    for lokasi, data in data_panen.items():
        totPadi += data['hasil_panen']['padi']
        totKedelai += data['hasil_panen']['kedelai']
        totKedelai += data['hasil_panen']['jagung']

def hasil():
    for lokasi, data in data_panen.items():
        padi[data['nama_lokasi']] = data['hasil_panen']['padi']
        kedelai[data['nama_lokasi']] = data['hasil_panen']['kedelai']

data_panen = {
    'lokasi1': {
        'nama_lokasi': 'Kebun A',
        'hasil_panen': {
            'padi': 1200,
            'jagung': 800,
            'kedelai': 500
        }
    },
    'lokasi2': {
        'nama_lokasi': 'Kebun B',
        'hasil_panen': {
            'padi': 1500,
            'jagung': 900,
            'kedelai': 450
        }
    },
    'lokasi3': {
        'nama_lokasi': 'Kebun C',
        'hasil_panen': {
            'padi': 1100,
            'jagung': 750,
            'kedelai': 600
        }
    },
    'lokasi4': {
        'nama_lokasi': 'Kebun D',
        'hasil_panen': {
            'padi': 1300,
            'jagung': 850,
            'kedelai': 550
        }
    },
    'lokasi5': {
        'nama_lokasi': 'Kebun E',
        'hasil_panen': {
            'padi': 1400,
            'jagung': 950,
            'kedelai': 480
        }
    }
}

print(f'Full data:\n{data_panen}')
print('\n')
print(f'Data lokasi 2:\n{data_panen['lokasi2']}')

jumlah()
print("\nTotal hasil panen Padi dan Kedelai:")
print(f"Padi: {totPadi}")
print(f"Kedelai: {totKedelai}")

print("\nTotal panen padi:")
for lokasi, total in padi.items():
    print(f"{lokasi}: {total}")
print("\nTotal panen kedelai:")
for lokasi, total in kedelai.items():
    print(f"{lokasi}: {total}")

print('\nKondisi lokasi:')
kriteria()
# Out:
# Full data:
# {'lokasi1': {'nama_lokasi': 'Kebun A', 'hasil_panen': {'padi': 1200, 'jagung': 800, 'kedelai': 500}}, 'lokasi2': {'nama_lokasi': 'Kebun B', 'hasil_panen': {'padi': 1500, 'jagung': 900, 'kedelai': 450}}, 'lokasi3': {'nama_lokasi': 'Kebun C', 'hasil_panen': {'padi': 1100, 'jagung': 750, 'kedelai': 600}}, 'lokasi4': {'nama_lokasi': 'Kebun D', 'hasil_panen': {'padi': 1300, 'jagung': 850, 'kedelai': 550}}, 'lokasi5': {'nama_lokasi': 'Kebun E', 'hasil_panen': {'padi': 1400, 'jagung': 950, 'kedelai': 480}}}
#
#
# Data lokasi 2:
# {'nama_lokasi': 'Kebun B', 'hasil_panen': {'padi': 1500, 'jagung': 900, 'kedelai': 450}}
#
# Total hasil panen Padi dan Kedelai:
# Padi: 6500
# Kedelai: 6830
#
# Total panen padi:
# Kebun A: 1200
# Kebun B: 1500
# Kebun C: 1100
# Kebun D: 1300
# Kebun E: 1400
#
# Total panen kedelai:
# Kebun A: 500
# Kebun B: 450
# Kebun C: 600
# Kebun D: 550
# Kebun E: 480
#
# Kondisi lokasi:
# Kebun A: Kondisi baik
# Kebun B: Butuh perhatian khusus
# ...

# %%
# 1. Tampilkan seluruh data dari data_panen termasuk nama lokasi dan hasil panen masing-masing.
# 2. Tampilkan jumlah hasil panen jagung dari lokasi2.
# 3. Tampilkan nama lokasi dari lokasi3.
# 4. Masukkan Jumlah Hasil Panen Padi dan Kedelai Setiap Lokasi ke Dalam Variabel yang Berbeda:
# 5. Buat variabel terpisah untuk menyimpan jumlah hasil panen padi dan kedelai dari setiap lokasi.
# 6. Buat Percabangan
# - Jika jumlah hasil panen padi lebih dari 1300 atau jagung lebih dari 800 di suatu lokasi, maka lokasi tersebut memerlukan perhatian khusus.
# - Jika tidak, maka lokasi tersebut dalam kondisi baik.
# 7. Push hasil pengerjaan kedalam GIT

# %%
# Soal 1
# git init
# git add Tugas.ipynb
# git remote add origin https://github.com/Vortexaint/TugasPemdas.git
# git remote -v
# git branch -m main
# git commit -m "Versi 1.0"
# git push -u origin main


# Soal 2
# PS D:\Kuliah\PemDas> git checkout 6e6ef2ab0074a3d72646d8161759b598ade311af       
# Note: switching to '6e6ef2ab0074a3d72646d8161759b598ade311af'.
# HEAD is now at 6e6ef2a initial commit
# PS D:\Kuliah\PemDas> git checkout 517ec24e2e325db0e8d5a21dff84e04bd715f0d7
# Previous HEAD position was 6e6ef2a initial commit
# HEAD is now at 517ec24 Versi 1.0

# Soal 3
# git branch Baru
# git checkout Baru
# git add Tugas.ipynb
# git commit -m "Masukkan ke branch Baru"

# Soal 4
# git add Tugas.ipynb
# git commit -m "Fix after pull" 
# git push -u origin main
# git push -u origin main --force // push paksa
# git pull origin main --allow-unrelated-histories // bila riwayat lokal dan reposity tidak sinkron

# Soal 5
# git remote add origin https://github.com/Vortexaint/TugasPemdas.git
# git pull origin main
# mkdir CloneProject
# cd CloneProject
# git clone https://github.com/diashitenas/AES256_QueryParam
# git clone --single-branch --branch main https://github.com/Vortexaint/TugasPemdas.git
# Out:
#   Cell In[24], line 25
#     Soal 5
#          ^
# SyntaxError: invalid syntax
